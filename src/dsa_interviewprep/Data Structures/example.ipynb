# %%
operations = ["1","2","+","C","5","D"]
operations[:len(operations)-1]
# Out:
# ['1', '2', '+', 'C', '5']

# %%
print(operations)
operations.pop()
print(operations)
# Out:
# ['1', '2', '+', 'C', '5', 'D']
# ['1', '2', '+', 'C', '5']

# %%
# Out:
# True
